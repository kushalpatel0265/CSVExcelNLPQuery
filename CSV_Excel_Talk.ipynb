# %% [markdown]
# <a href="https://colab.research.google.com/github/kushalpatel0265/CSVExcelNLPQuery/blob/main/CSV_Excel_Talk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandasai

# %%
import os
import pandas as pd
from pandasai import Agent

# Sample DataFrame
sales_by_country = pd.read_csv('CSV_file.csv')

# Connect 2nd CSV file together
#sales_by_country_2 = pd.read_csv('CSV_file_2.csv')

os.environ["PANDASAI_API_KEY"] = "Your API Key"

agent = Agent([sales_by_country])

# %%
agent.chat('Arrange the contry with their sales values in descending order')
# Out:
#      country  sales  year product_category continent
# 123    China   7000  2017      Electronics      Asia
# 381    China   7000  2019      Electronics      Asia
# 606    China   7000  2017      Electronics      Asia
# 40     China   7000  2023      Electronics      Asia
# 349    China   7000  2022      Electronics      Asia
# ..       ...    ...   ...              ...       ...
# 545    Spain   2100  2017         Clothing    Europe
# 723    Spain   2100  2023         Clothing    Europe
# 116  Nigeria   2100  2015      Electronics    Africa
# 722    Spain   2100  2018         Clothing    Europe
# 557  Nigeria   2100  2017      Electronics    Africa
#
# [1000 rows x 5 columns]

# %%
agent.chat('generate pie graph for year wise sales')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('generate graph category vs sales')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('generate pi chart for summary of product category')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 97, in execute
#     raise InvalidOutputValueMismatch(
# pandasai.exceptions.InvalidOutputValueMismatch: Value type <class 'module'> must match with type plot
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 97, in execute
#     raise InvalidOutputValueMismatch(
# pandasai.exceptions.InvalidOutputValueMismatch: Value type <class 'module'> must match with type plot
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 2]
# ...

# %%
agent.chat('generate graph for sales with equal frequency distribution')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Show all sales records from 2021')
# Out:
#             country  sales  year product_category      continent
# 0     United States   5000  2021      Electronics  North America
# 1    United Kingdom   3200  2021         Clothing         Europe
# 2            France   2900  2021      Electronics         Europe
# 3           Germany   4100  2021       Automotive         Europe
# 4             Italy   2300  2021             Food         Europe
# ..              ...    ...   ...              ...            ...
# 936          Brazil   3400  2021      Electronics  South America
# 949          Mexico   3100  2021       Automotive  North America
# 972          Sweden   3300  2021      Electronics         Europe
# 976           China   7000  2021      Electronics           Asia
# 981   United States   5000  2021      Electronics  North America
#
# [113 rows x 5 columns]

# %%
agent.chat('Show the first 10 rows of the sales data')
# Out:
#           country  sales  year product_category      continent
# 0   United States   5000  2021      Electronics  North America
# 1  United Kingdom   3200  2021         Clothing         Europe
# 2          France   2900  2021      Electronics         Europe
# 3         Germany   4100  2021       Automotive         Europe
# 4           Italy   2300  2021             Food         Europe
# 5           Spain   2100  2021         Clothing         Europe
# 6          Canada   2500  2021             Food  North America
# 7       Australia   2600  2021      Electronics        Oceania
# 8           Japan   4500  2021       Automotive           Asia
# 9           China   7000  2021      Electronics           Asia

# %%
agent.chat('Find all sales entries for the United States')
# Out:
#            country  sales  year product_category      continent
# 0    United States   5000  2021      Electronics  North America
# 22   United States   5000  2018      Electronics  North America
# 47   United States   5000  2017      Electronics  North America
# 56   United States   5000  2016      Electronics  North America
# 59   United States   5000  2022      Electronics  North America
# 65   United States   5000  2015      Electronics  North America
# 66   United States   5000  2019      Electronics  North America
# 85   United States   5000  2019      Electronics  North America
# 109  United States   5000  2017      Electronics  North America
# 111  United States   5000  2018      Electronics  North America
# 124  United States   5000  2018      Electronics  North America
# 148  United States   5000  2023      Electronics  North America
# 149  United States   5000  2023      Electronics  North America
# 171  United States   5000  2019      Electronics  North America
# ...

# %%
agent.chat('Calculate the total sales for each country')
# Out:
#            country   sales
# 0        Australia  132600
# 1           Brazil  173400
# 2           Canada  130000
# 3            China  336000
# 4            Egypt  101200
# 5           France  124700
# 6          Germany  266500
# 7            India  273000
# 8            Italy  121900
# 9            Japan  202500
# 10          Mexico  148800
# 11         Nigeria  107100
# 12          Russia  140800
# 13    South Africa  103400
# 14     South Korea  193500
# 15           Spain  117600
# 16          Sweden  194700
# 17          Turkey  132000
# 18  United Kingdom  163200
# 19   United States  250000

# %%
agent.chat('What is the average sales per year?')
# Out:
# 3412.9

# %%
agent.chat('Determine the maximum and minimum sales recorded for each product category')
# Out:
#                   max_sales  min_sales
# product_category
# Automotive             4500       2400
# Clothing               3200       2100
# Electronics            7000       2100
# Food                   6500       2300

# %%
agent.chat('Count the number of sales records per year')
# Out:
#       year
# 2018   129
# 2022   119
# 2021   113
# 2020   112
# 2015   112
# 2019   107
# 2017   104
# 2016   103
# 2023   101

# %%
agent.chat('Plot a line graph of total sales per year.')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Create a pie chart of the sales distribution by product category.')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('Visualize the trend of sales over the years for Electronics')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Give the continent wise total sales')
# Out:
#                  sales
# continent
# Africa          311700
# Asia           1005000
# Europe         1261400
# North America   528800
# Oceania         132600
# South America   173400

# %%
agent.chat('Generate the graph for the continent vs total sales')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Summarize total sales by country and year')
# Out:
#            country  year  sales
# 0        Australia  2015  15600
# 1        Australia  2016   5200
# 2        Australia  2017  15600
# 3        Australia  2018  28600
# 4        Australia  2019  15600
# ..             ...   ...    ...
# 174  United States  2019  25000
# 175  United States  2020  30000
# 176  United States  2021  40000
# 177  United States  2022  20000
# 178  United States  2023  15000
#
# [179 rows x 3 columns]

# %%
agent.chat('Generate pie chart for sales continent wise')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('Generate bar chart for sales continent wise')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Generate histogram chart for sales continent wise')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('Generate box plot for sales continent wise')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('give the sql code for country which has highest sales')
# Out:
# 'The country with the highest sales is China.'
